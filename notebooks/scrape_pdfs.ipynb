# %%
from bs4 import BeautifulSoup
import requests

# %%
import time
import random

def be_nice():
    """Adds a random sleep between 0s and 1s"""
    time.sleep(random.random())

# %%
def log_progress(sequence, every=None, size=None, name='Items'):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)     # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{name}: {index} / ?'.format(
                        name=name,
                        index=index
                    )
                else:
                    progress.value = index
                    label.value = u'{name}: {index} / {size}'.format(
                        name=name,
                        index=index,
                        size=size
                    )
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = "{name}: {index}".format(
            name=name,
            index=str(index or '?')
        )

# %%
start_url = 'https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset={}'
def crawl_pages():
    """Crawls all pages of the archives and saves them in dumps/html"""
    offset = 0
    while True:
        current_url = start_url.format(offset)
        print('Requesting {}'.format(current_url))
        r = requests.get(current_url)
        r.raise_for_status()
        with open('./dumps/html/{}.html'.format(offset), 'wb') as f:
            f.write(r.content)
        offset += 10
        be_nice()

# %%
crawl_pages()
# Out:
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=0
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=10
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=20
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=30
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=40
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=50
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=60
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=70
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=80
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=90
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=100
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=110
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=120
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=130
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=140
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=150
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=160
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=170
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=180
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=190
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=200
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=210
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=220
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=230
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=240
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=250
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=260
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=270
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=280
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=290
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=300
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=310
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=320
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=330
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=340
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=350
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=360
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=370
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=380
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=390
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=400
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=410
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=420
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=430
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=440
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=450
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=460
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=470
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=480
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=490
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=500
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=510
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=520
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=530
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=540
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=550
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=560
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=570
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=580
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=590
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=600
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=610
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=620
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=630
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=640
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=650
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=660
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=670
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=680
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=690
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=700
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=710
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=720
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=730
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=740
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=750
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=760
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=770
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=780
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=790
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=800
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=810
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=820
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=830
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=840
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=850
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=860
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=870
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=880
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=890
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=900
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=910
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=920
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=930
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=940
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=950
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=960
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=970
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=980
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=990
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1000
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1010
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1020
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1030
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1040
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1050
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1060
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1070
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1080
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1090
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1100
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1110
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1120
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1130
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1140
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1150
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1160
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1170
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1180
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1190
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1200
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1210
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1220
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1230
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1240
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1250
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1260
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1270
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1280
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1290
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1300
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1310
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1320
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1330
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1340
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1350
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1360
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1370
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1380
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1390
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1400
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1410
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1420
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1430
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1440
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1450
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1460
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1470
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1480
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1490
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1500
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1510
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1520
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1530
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1540
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1550
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1560
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1570
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1580
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1590
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1600
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1610
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1620
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1630
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1640
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1650
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1660
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1670
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1680
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1690
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1700
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1710
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1720
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1730
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1740
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1750
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1760
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1770
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1780
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1790
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1800
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1810
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1820
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1830
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1840
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1850
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1860
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1870
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1880
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1890
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1900
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1910
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1920
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1930
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1940
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1950
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1960
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1970
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1980
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=1990
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2000
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2010
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2020
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2030
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2040
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2050
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2060
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2070
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2080
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2090
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2100
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2110
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2120
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2130
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2140
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2150
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2160
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2170
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2180
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2190
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2200
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2210
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2220
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2230
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2240
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2250
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2260
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2270
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2280
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2290
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2300
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2310
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2320
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2330
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2340
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2350
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2360
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2370
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2380
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2390
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2400
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2410
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2420
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2430
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2440
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2450
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2460
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2470
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2480
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2490
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2500
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2510
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2520
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2530
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2540
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2550
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2560
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2570
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2580
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2590
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2600
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2610
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2620
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2630
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2640
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2650
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2660
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2670
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2680
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2690
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2700
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2710
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2720
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2730
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2740
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2750
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2760
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2770
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2780
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2790
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2800
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2810
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2820
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2830
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2840
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2850
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2860
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2870
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2880
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2890
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2900
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2910
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2920
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2930
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2940
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2950
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2960
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2970
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2980
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=2990
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3000
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3010
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3020
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3030
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3040
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3050
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3060
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3070
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3080
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3090
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3100
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3110
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3120
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3130
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3140
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3150
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3160
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3170
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3180
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=3190
# ...
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8480
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8490
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8500
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8510
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8520
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8530
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8540
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8550
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8560
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8570
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8580
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8590
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8600
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8610
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8620
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8630
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8640
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8650
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8660
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8670
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8680
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8690
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8700
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8710
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8720
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8730
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8740
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8750
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8760
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8770
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8780
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8790
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8800
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8810
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8820
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8830
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8840
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8850
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8860
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8870
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8880
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8890
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8900
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8910
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8920
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8930
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8940
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8950
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8960
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8970
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8980
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=8990
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9000
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9010
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9020
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9030
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9040
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9050
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9060
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9070
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9080
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9090
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9100
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9110
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9120
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9130
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9140
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9150
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9160
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9170
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9180
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9190
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9200
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9210
# Requesting https://www.bundestag.de/ajax/filterlist/de/dokumente/-/442146/h_bcc811783a1be39391c6f3248151306d?limit=10000&noFilterSet=true&offset=9220
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-089894b99060> in <module>()
# ----> 1 crawl_pages()
#
# <ipython-input-4-5183b22db6a5> in crawl_pages()
#       6         current_url = start_url.format(offset)
#       7         print('Requesting {}'.format(current_url))
# ----> 8         r = requests.get(current_url)
#       9         r.raise_for_status()
#      10         with open('./dumps/html/{}.html'.format(offset), 'wb') as f:
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     594
#     595         # Send the request
# --> 596         r = adapter.send(request, **kwargs)
#     597
#     598         # Total elapsed time of the request (approximately)
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   timeout=timeout_obj,
#     594                                                   body=body, headers=headers,
# --> 595                                                   chunked=chunked)
#     596
#     597             # If we're going to release the connection in ``finally:``, then
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     350         # Trigger any extra validation we need to do.
#     351         try:
# --> 352             self._validate_conn(conn)
#     353         except (SocketTimeout, BaseSSLError) as e:
#     354             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     829         # Force connect early to allow us to validate the connection.
#     830         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 831             conn.connect()
#     832
#     833         if not conn.is_verified:
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     252     def connect(self):
#     253         # Add certificate verification
# --> 254         conn = self._new_conn()
#     255
#     256         resolved_cert_reqs = resolve_cert_reqs(self.cert_reqs)
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     140         try:
#     141             conn = connection.create_connection(
# --> 142                 (self.host, self.port), self.timeout, **extra_kw)
#     143
#     144         except SocketTimeout as e:
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      86             if source_address:
#      87                 sock.bind(source_address)
# ---> 88             sock.connect(sa)
#      89             return sock
#      90
#
# KeyboardInterrupt:

# %%
import glob

def extract_pdf_links():
    dumped_html = glob.glob('./dumps/html/*')
    for file in log_progress(dumped_html, every=1):
        with open(file, 'r') as f:
            soup = BeautifulSoup(f, 'lxml')
            for anchor in soup.select('a[href$=".pdf"]'):
                yield anchor['href']

def download_all(url_iterator, path):
    for url in log_progress(url_iterator, every=1):
        r = requests.get(url, stream=True)
        try:
            r.raise_for_status()
        except:
            print('URL {}'.format(url))
            print('Status {}'.format(r.status_code))
            continue
        filename = url.split('/')[-1]
        f = open(path.strip('/') + '/' + filename, 'wb')
        for chunk in r.iter_content(chunk_size=512 * 1024): 
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)
        f.close()
        be_nice()

# %%
for u in log_progress(download_all(extract_pdf_links(), './dumps/pdf'), every=1):
    pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-d8b56551908d> in <module>()
# ----> 1 for u in log_progress(download_all(extract_pdf_links(), './dumps/pdf'), every=1):
#       2     pass
#
# <ipython-input-24-cf879fbb25d8> in download_all(url_iterator, path)
#      11 def download_all(url_iterator, path):
#      12     for url in log_progress(url_iterator, every=1):
# ---> 13         r = requests.get(url, stream=True)
#      14         try:
#      15             r.raise_for_status()
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     594
#     595         # Send the request
# --> 596         r = adapter.send(request, **kwargs)
#     597
#     598         # Total elapsed time of the request (approximately)
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   timeout=timeout_obj,
#     594                                                   body=body, headers=headers,
# --> 595                                                   chunked=chunked)
#     596
#     597             # If we're going to release the connection in ``finally:``, then
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     361             conn.request_chunked(method, url, **httplib_request_kw)
#     362         else:
# --> 363             conn.request(method, url, **httplib_request_kw)
#     364
#     365         # Reset the timeout for the recv() on the socket
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     165
#     166     def connect(self):
# --> 167         conn = self._new_conn()
#     168         self._prepare_conn(conn)
#     169
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     140         try:
#     141             conn = connection.create_connection(
# --> 142                 (self.host, self.port), self.timeout, **extra_kw)
#     143
#     144         except SocketTimeout as e:
#
# /Users/arnold/Develop/rbb/crawlers/venv/lib/python3.6/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      86             if source_address:
#      87                 sock.bind(source_address)
# ---> 88             sock.connect(sa)
#      89             return sock
#      90
#
# KeyboardInterrupt:
